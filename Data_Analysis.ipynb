# %%
# Importing the librarys
import pandas as pd
import numpy as np
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt

# %%
#Importing the dataset
data= pd.read_csv("D:\Excel\Data_set1.csv")
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Data Cleaning

# %%
rows,columns = data.shape
print(rows)
print(columns)
# Out:
# 9551
# 21

# %%
data.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Shows that all columns names
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
data.drop_duplicates()
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml? Gurme           208         ??stanbul
# 9547        5908749              Ceviz A??ac?           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112               A???k Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ##  Level 1:
# ##             Task 1:
# ##                       Determine the top three most common cuisines in the dataset

# %%
data['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
data['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
cuisine_counts = data['Cuisines'].value_counts()

# Get the top three most common cuisines
top_three_cuisines = cuisine_counts.head(3)

print(top_three_cuisines)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
cuisine_lists = data['Cuisines'].str.split(',')
cuisine_lists
# Out:
# 0              [French,  Japanese,  Desserts]
# 1                                  [Japanese]
# 2       [Seafood,  Asian,  Filipino,  Indian]
# 3                          [Japanese,  Sushi]
# 4                         [Japanese,  Korean]
#                         ...
# 9546                                [Turkish]
# 9547      [World Cuisine,  Patisserie,  Cafe]
# 9548                [Italian,  World Cuisine]
# 9549                        [Restaurant Cafe]
# 9550                                   [Cafe]
# Name: Cuisines, Length: 9551, dtype: object

# %%
cuisine_lists = data['Cuisines'].str.split(',')

# Flatten the list to remove nested lists
cuisines = [cuisine.strip() for sublist in cuisine_lists if isinstance(sublist, list) for cuisine in sublist]

#  Use Counter to count occurrences of each cuisine
cuisine_counts = Counter(cuisines)

#  Get the top most 3 common cuisines
top_cuisines = cuisine_counts.most_common(3) 

print("Top 3 most common cuisines: ",top_cuisines)
# Out:
# Top 3 most common cuisines:  [('North Indian', 3960), ('Chinese', 2735), ('Fast Food', 1986)]

# %% [markdown]
# ## LEVEL  1:
# ## TASK 1:
# ## Calculate the percentage of restaurants that serve each of the top cuisines.

# %%
data['Cuisines'] = data['Cuisines'].fillna('')
total_restaurants = len(data)
top_cuisines = ['North Indian','Chinese','Fast Food']
percentage_per_cuisine = {}
for cuisine in top_cuisines:
    
    # Count the number of restaurants serving the current cuisine
    num_restaurants_serving_cuisine = data[data['Cuisines'].str.contains(cuisine)].shape[0]
    
    # Calculate the percentage
    percentage = (num_restaurants_serving_cuisine / total_restaurants) * 100
    
    # Store the percentage
    percentage_per_cuisine[cuisine] = percentage

print("Percentage of restaurants serving each of the top cuisines:")
for cuisine, percentage in percentage_per_cuisine.items():
    print(f"{cuisine}: {percentage:.2f}%")
# Out:
# Percentage of restaurants serving each of the top cuisines:
# North Indian: 41.46%
# Chinese: 28.61%
# Fast Food: 20.80%

# %% [markdown]
# ## TASK 2
# ## CITY  ANALYSIS
# ### Identify the city with the highest number of restaurants in the dataset.

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
max_restaurants = data["City"].value_counts()
print("City with the highest number of restaurants:  ")
print(max_restaurants.head())
# Out:
# City with the highest number of restaurants:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: count, dtype: int64

# %% [markdown]
# ## Calculate the average rating for restaurants in each city

# %%
average_rating_per_city = data.groupby('City')['Aggregate rating'].mean()

print(average_rating_per_city)
# Out:
# City
# ??stanbul          4.292857
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
#                      ...
# Waterloo           3.650000
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# Name: Aggregate rating, Length: 141, dtype: float64

# %% [markdown]
# ## Determine the city with the highest average rating.

# %%
city_with_highest_rating = average_rating_per_city.idxmax()
highest_average_rating = average_rating_per_city.max()

print("City with the highest average rating:", city_with_highest_rating)
print("Average rating:", highest_average_rating)
# Out:
# City with the highest average rating: Inner City
# Average rating: 4.9

# %% [markdown]
# ## TASK 3:
# ## PRICE  RANGE DISTRIBUTION
# ## Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants

# %%
plt.figure(figsize=(10, 6))
data['Price range'].value_counts().sort_index().plot(kind='bar', color='pink')
plt.title('Distribution of Price Ranges Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Create the percentage of restaurants in each price range category.

# %%
price_range_counts = data['Price range'].value_counts()
total_restaurants = price_range_counts.sum()
percentage_per_price_range = (price_range_counts / total_restaurants) * 100

# Plot the percentage of restaurants in each price range category
plt.figure(figsize=(10, 6))
percentage_per_price_range.sort_index().plot(kind='bar', color='skyblue')
plt.title('Percentage of Restaurants in Each Price Range Category')
plt.xlabel('Price Range')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## TASK 4:
#
# ## Online Delivery
# ## Determine the percentage of resturants that offer online delivery

# %%
data["Has Online delivery"].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
total_restaurants = len(data)
restaurants_with_online_delivery = data['Has Online delivery'].value_counts().get('Yes', 0)

# Calculate the percentage of restaurants that offer online delivery
percentage_online_delivery = (restaurants_with_online_delivery / total_restaurants) * 100

print("Percentage of restaurants that offer online delivery:", percentage_online_delivery)
# Out:
# Percentage of restaurants that offer online delivery: 25.662234321013504

# %% [markdown]
# ## Compare the average ratings of restaurants with and without online delivery.

# %%
data['Aggregate rating'] = pd.to_numeric(data['Aggregate rating'], errors='coerce')


# Calculate the average rating for restaurants with and without online delivery
avg_rating_with_delivery = data[data['Has Online delivery'] == 'Yes']['Aggregate rating'].mean()
avg_rating_without_delivery = data[data['Has Online delivery'] == 'No']['Aggregate rating'].mean()

print('Average rating of restaurants with online delivery: ',avg_rating_with_delivery)
print('Average rating of restaurants with online delivery: ',avg_rating_without_delivery)
# Out:
# Average rating of restaurants with online delivery:  3.2488372093023257
# Average rating of restaurants with online delivery:  2.465295774647887

# %% [markdown]
# ## Level 2:
# ## Task 1:
# ## Restaurant Ratings
# ### Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
ratings = data["Aggregate rating"]

# Plot a histogram to visualize the distribution of ratings
plt.hist(ratings, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Aggregate Ratings')

# Show the plot
plt.show()

# Identify the most common rating range
most_common_range = ratings.mode()
print("Most common rating range:", most_common_range[0])
# Out:
# Most common rating range: 0.0

# %% [markdown]
# ###  Calculate the average number of votes receied by resstaurants

# %%
# Calculate the average number of votes received by restaurants
average_votes = data["Votes"].mean()

print("Average number of votes received by restaurants:", average_votes)
# Out:
# Average number of votes received by restaurants: 156.909747670401

# %% [markdown]
# ## Task 2:
# ## Cuisine Combination
# ### Identify the most common combinations of cuisines in the dataset

# %%
# Convert non-string values in 'Cuisines' column to strings
data['Cuisines'] = data['Cuisines'].astype(str)

# Split the cuisines string into a list of cuisines
data['Cuisines'] = data['Cuisines'].str.split(', ')

# Create a list of all unique cuisines
unique_cuisines = data['Cuisines'].explode().unique()

# Create a new DataFrame with binary columns for each cuisine
cuisine_data = pd.DataFrame(0, index=data.index, columns=unique_cuisines)

# Assign 1 to the binary columns where the respective cuisine is present
for cuisine in unique_cuisines:
    cuisine_data[cuisine] = data['Cuisines'].apply(lambda x: 1 if cuisine in x else 0)

# Concatenate the original DataFrame with the new cuisine DataFrame
data_with_cuisines = pd.concat([data, cuisine_data], axis=1)

# Convert lists in 'Cuisines' column to tuples
data_with_cuisines['Cuisines'] = data_with_cuisines['Cuisines'].apply(tuple)

# Identify the most common combinations of cuisines
common_cuisine_combinations = data_with_cuisines.groupby('Cuisines').size().sort_values(ascending=False).head(10)

print("Top 10 most common combinations of cuisines:")
print(common_cuisine_combinations)
# Out:
# Top 10 most common combinations of cuisines:
# Cuisines
# (North Indian,)                     936
# (North Indian, Chinese)             511
# (Chinese,)                          354
# (Fast Food,)                        354
# (North Indian, Mughlai)             334
# (Cafe,)                             299
# (Bakery,)                           218
# (North Indian, Mughlai, Chinese)    197
# (Bakery, Desserts)                  170
# (Street Food,)                      149
# dtype: int64

# %%
data['Cuisines'].value_counts().head(10)
# Out:
# Cuisines
# [North Indian]                      936
# [North Indian, Chinese]             511
# [Chinese]                           354
# [Fast Food]                         354
# [North Indian, Mughlai]             334
# [Cafe]                              299
# [Bakery]                            218
# [North Indian, Mughlai, Chinese]    197
# [Bakery, Desserts]                  170
# [Street Food]                       149
# Name: count, dtype: int64

# %% [markdown]
# ## Determine if certain cuisine combinations tend to have higher ratings

# %%
#Convert the 'Cuisines' column to a string
data['Cuisines'] = data['Cuisines'].astype(str)

# Calculate the average rating for each unique combination of cuisines
average_rating_by_cuisine_combination = data.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

print("Average rating for each unique combination of cuisines:")
print(average_rating_by_cuisine_combination)
# Out:
# Average rating for each unique combination of cuisines:
# Cuisines
# ['World Cuisine']                                           4.9
# ['American', 'BBQ', 'Sandwich']                             4.9
# ['Italian', 'Deli']                                         4.9
# ['Sunda', 'Indonesian']                                     4.9
# ['Hawaiian', 'Seafood']                                     4.9
#                                                            ...
# ['Beverages', 'Healthy Food']                               0.0
# ['American', 'Italian', 'North Indian', 'Chinese']          0.0
# ['South Indian', 'Fast Food', 'North Indian', 'Chinese']    0.0
# ['Awadhi', 'North Indian']                                  0.0
# ['North Indian', 'South Indian', 'Mithai']                  0.0
# Name: Aggregate rating, Length: 1826, dtype: float64

# %% [markdown]
# ## TASK : 4 :- Restaurants chains
# ## Identify if there are any restaurants chains present in the dataset

# %%
chain_restaurants = data["Restaurant Name"].value_counts()

# Filter out restaurants with more than one branch
chain_restaurants = chain_restaurants[chain_restaurants > 1]

# List the restaurant chains
restaurant_chains = chain_restaurants.index.tolist()

# Print the restaurant chains
print("Restaurant chains in the dataset:")
for chain in restaurant_chains:
    print(chain)
# Out:
# Restaurant chains in the dataset:
# Cafe Coffee Day
# Domino's Pizza
# Subway
# Green Chick Chop
# McDonald's
# Keventers
# Pizza Hut
# Giani
# Baskin Robbins
# Barbeque Nation
# Giani's
# Barista
# Dunkin' Donuts
# Costa Coffee
# Pind Balluchi
# Wah Ji Wah
# Twenty Four Seven
# Pizza Hut Delivery
# Sagar Ratna
# Republic of Chicken
# KFC
# Starbucks
# Chaayos
# Burger King
# Haldiram's
# Shree Rathnam
# Frontier
# Moti Mahal Delux
# Bikanervala
# Aggarwal Sweets
# Behrouz Biryani
# Karim's
# Bikaner Sweets
# Chicago Pizza
# Apni Rasoi
# 34, Chowringhee Lane
# Wow! Momo
# Madras Cafe
# Burger Point
# Gopala
# Shama Chicken Corner
# Berco's
# Nirula's Ice Cream
# Sardar A Pure Meat Shop
# Yo! China
# Cocoberry
# Punjabi Tadka
# Angels in my Kitchen
# Faasos
# Ovenstory Pizza
# Chowringhee
# Punjabi Chaap Corner
# Kebab Xpress
# Nazeer Foods
# RollsKing
# Tpot
# Mocha
# Dolce Gelato
# Tibb's Frankie
# The Yellow Chilli
# Slice of Italy
# BTW
# Khan Chacha
# Chawla's?_
# China Town
# ...

# %% [markdown]
# ## Analyze the ratings and popularity of different restaurant chains.

# %%
# Extract restaurant chains from restaurant names
data['Restaurant Chain'] = data['Restaurant Name'].apply(lambda x: ', '.join(x.split(',')[0:2]))

# Group by restaurant chain and calculate average rating and total votes
chain_ratings_popularity = data.groupby('Restaurant Chain').agg({
    'Aggregate rating': 'mean',
    'Votes': 'sum'
})

# Sort by average rating in descending order
chain_ratings_popularity = chain_ratings_popularity.sort_values(by='Aggregate rating', ascending=False)

# Print the analysis
print("Restaurant Chains - Ratings and Popularity Analysis:")
print(chain_ratings_popularity)
# Out:
# Restaurant Chains - Ratings and Popularity Analysis:
#                                Aggregate rating  Votes
# Restaurant Chain
# Ingleside Village Pizza                     4.9    478
# McGuire's Irish Pub & Brewery               4.9   2238
# Duck & Waffle                               4.9    706
# Ooma                                        4.9    365
# Indian Accent - The Manor                   4.9   1934
# ...                                         ...    ...
# Cafe Krisa                                  0.0      0
# Parantha Point                              0.0      1
# Parantha on Call                            0.0      0
# Paras Chicken Point                         0.0      1
# Laxmi Food Corner                           0.0      0
#
# [7446 rows x 2 columns]

# %% [markdown]
# ## LEVEL 3 : Task: Restaurant Reviews
# ## TASK 1 : - Analyze the text reviews to identify the most common positive and negative keywords.

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter

# Tokenize the text reviews and perform sentiment analysis
sid =SentimentIntensityAnalyzer()

positive_keywords = []
negative_keywords = []

for review in data['Rating text']:
    tokens = word_tokenize(review.lower())  # Convert to lowercase for consistency
    sentiment_score = sid.polarity_scores(review)['compound']  # Get sentiment score
    
    # Determine if the review is positive or negative based on sentiment score
    if sentiment_score >= 0.05:
        positive_keywords.extend(tokens)
    elif sentiment_score <= -0.05:
        negative_keywords.extend(tokens)

# Count the frequency of positive and negative keywords
positive_keyword_counts = Counter(positive_keywords)
negative_keyword_counts = Counter(negative_keywords)

# Get the most common positive and negative keywords
most_common_positive_keywords = positive_keyword_counts.most_common(5)
most_common_negative_keywords = negative_keyword_counts.most_common(5)

# Print the results
print("Most common positive keywords:")
for keyword, count in most_common_positive_keywords:
    print(keyword, count)

print("\nMost common negative keywords:")
for keyword, count in most_common_negative_keywords:
    print(keyword, count)
# Out:
# Most common positive keywords:
# good 3179
# very 1079
# excellent 301
#
# Most common negative keywords:
# poor 186

# %% [markdown]
# ## Calculate the average length of reviews and explore if there is a relationship between review length and rating.

# %%
# Calculate the length of each review and add it as a new column
data['Review Length'] = data['Rating text'].apply(lambda x: len(x))

# Calculate the average length of reviews
average_review_length = data['Review Length'].mean()

# Explore the relationship between review length and rating (correlation)
correlation = data['Review Length'].corr(data['Aggregate rating'])

# Print the results
print("Average length of reviews:", average_review_length)
print("Correlation between review length and rating:", correlation)
# Out:
# Average length of reviews: 7.020730813527379
# Correlation between review length and rating: -0.47888483813493266

# %% [markdown]
# ## TASK 2 : Votes Analysis
# ## Identify the restaurants with the highest and lowest number of votes

# %%
# Identify the restaurant with the highest number of votes
highest_votes_restaurant = data.loc[data['Votes'].idxmax()]

# Identify the restaurant with the lowest number of votes
lowest_votes_restaurant = data.loc[data['Votes'].idxmin()]

# Print the results
print("Restaurant with the highest number of votes:")
print(highest_votes_restaurant)

print("\nRestaurant with the lowest number of votes:")
print(lowest_votes_restaurant)
# Out:
# Restaurant with the highest number of votes:
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                       77.640709
# Latitude                                                        12.979166
# Cuisines                                 ['Italian', 'American', 'Pizza']
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# ...

# %% [markdown]
# ## Analyze if there is a correlation between the number of votes and the rating of a restaurant.

# %%
# Calculate the correlation coefficient between number of votes and rating
correlation = data['Votes'].corr(data['Aggregate rating'])

# Print the correlation coefficient
print("Correlation between number of votes and rating:", correlation)
# Out:
# Correlation between number of votes and rating: 0.31369058419541135

# %% [markdown]
# ## TASK 3: Price Range vs. Online Delivery and Table Booking
# ## Analyze if there is a relationship between the price range and the availability of online delivery and table booking

# %%
# Calculate the percentage of restaurants within each price range that offer online delivery and table booking
price_range_stats = data.groupby('Price range').agg({
    'Has Online delivery': lambda x: (x == 'Yes').mean() * 100,
    'Has Table booking': lambda x: (x == 'Yes').mean() * 100
}).reset_index()

# Rename columns for clarity
price_range_stats.rename(columns={'Has Online delivery': 'Online Delivery (%)', 'Has Table booking': 'Table Booking (%)'}, inplace=True)

# Print the results
print("Percentage of restaurants offering online delivery and table booking by price range:")
print(price_range_stats)
# Out:
# Percentage of restaurants offering online delivery and table booking by price range:
#    Price range  Online Delivery (%)  Table Booking (%)
# 0            1            15.774077           0.022502
# 1            2            41.310633           7.677482
# 2            3            29.190341          45.738636
# 3            4             9.044369          46.757679

# %% [markdown]
# Consider the above result:-
#                          The relationship between the price range and online delivery is negatively correlated.
#                          The relationship between the price range and Table Booking is positively correlated

# %% [markdown]
# ##  Determine if higher-priced restaurants are more likely to offer these services.

# %%
# Convert 'Has Online delivery' and 'Has Table booking' columns to binary values (0 for No, 1 for Yes)
data['Has Online delivery'] = (data['Has Online delivery'] == 'Yes').astype(int)
data['Has Table booking'] = (data['Has Table booking'] == 'Yes').astype(int)

# Calculate the average availability of online delivery and table booking for each price range
price_range_availability = data.groupby('Price range').agg({
    'Has Online delivery': 'mean',
    'Has Table booking': 'mean'
}).reset_index()

# Print the results
print("Average availability of online delivery and table booking by price range:")
print(price_range_availability)
# Out:
# Average availability of online delivery and table booking by price range:
#    Price range  Has Online delivery  Has Table booking
# 0            1             0.157741           0.000225
# 1            2             0.413106           0.076775
# 2            3             0.291903           0.457386
# 3            4             0.090444           0.467577

# %% [markdown]
# consider the price range higher priced  restaurents are more likely to offer table booking services
